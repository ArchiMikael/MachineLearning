# %% [markdown]
# **Шубин Михаил, гр. 3821Б1ПМоп3**

# %% [markdown]
# ## **0. Описать задачу словами**
#
#         Решается задача регрессии оценки риска при выдаче кредита (или одобрении долга) для клиента на основании его данных (личных, данных о работе и т.д.)

# %% [markdown]
# ## **1. Прочитать данные**

# %%
# Подключение модулей
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

# %%
# Загрузка датасета
raw_data = pd.read_csv("C:/Users/archi_ikpt0er/Desktop/ML/Data/Loan.csv")
raw_data = raw_data.drop(['ApplicationDate', 'LoanApproved'], axis=1) # Удаление даты, поскольку она не имеет смыслового влияния на задачу, но добавляет лишнюю сложность, и признака для бинарной классификации
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 34 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         20000 non-null  int64
#  1   AnnualIncome                20000 non-null  int64
#  2   CreditScore                 20000 non-null  int64
#  3   EmploymentStatus            20000 non-null  object
#  4   EducationLevel              20000 non-null  object
#  5   Experience                  20000 non-null  int64
#  6   LoanAmount                  20000 non-null  int64
#  7   LoanDuration                20000 non-null  int64
#  8   MaritalStatus               20000 non-null  object
#  9   NumberOfDependents          20000 non-null  int64
#  10  HomeOwnershipStatus         20000 non-null  object
#  11  MonthlyDebtPayments         20000 non-null  int64
#  12  CreditCardUtilizationRate   20000 non-null  float64
#  13  NumberOfOpenCreditLines     20000 non-null  int64
#  14  NumberOfCreditInquiries     20000 non-null  int64
#  15  DebtToIncomeRatio           20000 non-null  float64
#  16  BankruptcyHistory           20000 non-null  int64
#  17  LoanPurpose                 20000 non-null  object
#  18  PreviousLoanDefaults        20000 non-null  int64
#  19  PaymentHistory              20000 non-null  int64
#  20  LengthOfCreditHistory       20000 non-null  int64
#  21  SavingsAccountBalance       20000 non-null  int64
#  22  CheckingAccountBalance      20000 non-null  int64
#  23  TotalAssets                 20000 non-null  int64
#  24  TotalLiabilities            20000 non-null  int64
#  25  MonthlyIncome               20000 non-null  float64
#  26  UtilityBillsPaymentHistory  20000 non-null  float64
#  27  JobTenure                   20000 non-null  int64
#  28  NetWorth                    20000 non-null  int64
#  29  BaseInterestRate            20000 non-null  float64
#  30  InterestRate                20000 non-null  float64
#  31  MonthlyLoanPayment          20000 non-null  float64
#  32  TotalDebtToIncomeRatio      20000 non-null  float64
#  33  RiskScore                   20000 non-null  float64
# dtypes: float64(9), int64(20), object(5)
# memory usage: 5.2+ MB

# %%
numeric_feat = []
for feat in raw_data.keys():
  if ((raw_data.dtypes[feat] == 'float64' or raw_data.dtypes[feat] == 'int64') and feat != 'RiskScore'):
      numeric_feat.append(feat)

numeric_feat
# Out:
# ['Age',
#  'AnnualIncome',
#  'CreditScore',
#  'Experience',
#  'LoanAmount',
#  'LoanDuration',
#  'NumberOfDependents',
#  'MonthlyDebtPayments',
#  'CreditCardUtilizationRate',
#  'NumberOfOpenCreditLines',
#  'NumberOfCreditInquiries',
#  'DebtToIncomeRatio',
#  'BankruptcyHistory',
#  'PreviousLoanDefaults',
#  'PaymentHistory',
#  'LengthOfCreditHistory',
#  'SavingsAccountBalance',
#  'CheckingAccountBalance',
#  'TotalAssets',
#  'TotalLiabilities',
#  'MonthlyIncome',
#  'UtilityBillsPaymentHistory',
#  'JobTenure',
#  'NetWorth',
#  'BaseInterestRate',
#  'InterestRate',
#  'MonthlyLoanPayment',
#  'TotalDebtToIncomeRatio']

# %% [markdown]
# ## **2. Визуализировать данные и вычислить основные характеристики (среднее, разброс, корреляционную матрицу и т.д.). Интерпретировать.**

# %%
# Основные характеристики
raw_data.describe()
# Out:
#                 Age   AnnualIncome   CreditScore    Experience     LoanAmount  \
# count  20000.000000   20000.000000  20000.000000  20000.000000   20000.000000
# mean      39.752600   59161.473550    571.612400     17.522750   24882.867800
# std       11.622713   40350.845168     50.997358     11.316836   13427.421217
# min       18.000000   15000.000000    343.000000      0.000000    3674.000000
# 25%       32.000000   31679.000000    540.000000      9.000000   15575.000000
# 50%       40.000000   48566.000000    578.000000     17.000000   21914.500000
# 75%       48.000000   74391.000000    609.000000     25.000000   30835.000000
# max       80.000000  485341.000000    712.000000     61.000000  184732.000000
#
#        LoanDuration  NumberOfDependents  MonthlyDebtPayments  \
# count  20000.000000        20000.000000         20000.000000
# mean      54.057000            1.517300           454.292700
# std       24.664857            1.386325           240.507609
# min       12.000000            0.000000            50.000000
# 25%       36.000000            0.000000           286.000000
# 50%       48.000000            1.000000           402.000000
# 75%       72.000000            2.000000           564.000000
# max      120.000000            5.000000          2919.000000
#
#        CreditCardUtilizationRate  NumberOfOpenCreditLines  ...  \
# count               20000.000000             20000.000000  ...
# mean                    0.286381                 3.023350  ...
# std                     0.159793                 1.736161  ...
# min                     0.000974                 0.000000  ...
# 25%                     0.160794                 2.000000  ...
# 50%                     0.266673                 3.000000  ...
# 75%                     0.390634                 4.000000  ...
# max                     0.917380                13.000000  ...
#
#        TotalLiabilities  MonthlyIncome  UtilityBillsPaymentHistory  \
# count      2.000000e+04   20000.000000                20000.000000
# mean       3.625241e+04    4891.715521                    0.799918
# std        4.725151e+04    3296.771598                    0.120665
# min        3.720000e+02    1250.000000                    0.259203
# 25%        1.119675e+04    2629.583333                    0.727379
# 50%        2.220300e+04    4034.750000                    0.820962
# 75%        4.314650e+04    6163.000000                    0.892333
# max        1.417302e+06   25000.000000                    0.999433
#
#           JobTenure      NetWorth  BaseInterestRate  InterestRate  \
# count  20000.000000  2.000000e+04      20000.000000  20000.000000
# mean       5.002650  7.229432e+04          0.239124      0.239110
# std        2.236804  1.179200e+05          0.035509      0.042205
# min        0.000000  1.000000e+03          0.130101      0.113310
# 25%        3.000000  8.734750e+03          0.213889      0.209142
# 50%        5.000000  3.285550e+04          0.236157      0.235390
# 75%        6.000000  8.882550e+04          0.261533      0.265532
# max       16.000000  2.603208e+06          0.405029      0.446787
#
#        MonthlyLoanPayment  TotalDebtToIncomeRatio     RiskScore
# count        20000.000000            20000.000000  20000.000000
# mean           911.607052                0.402182     50.766780
# std            674.583473                0.338924      7.778262
# min             97.030193                0.016043     28.800000
# 25%            493.763700                0.179693     46.000000
# 50%            728.511452                0.302711     52.000000
# 75%           1112.770759                0.509214     56.000000
# max          10892.629520                4.647657     84.000000
#
# [8 rows x 29 columns]

# %%
# Матрица корреляции
corr_data = raw_data.corr(numeric_only=True)
corr_data
# Out:
#                                  Age  AnnualIncome  CreditScore  Experience  \
# Age                         1.000000      0.144774     0.323243    0.982980
# AnnualIncome                0.144774      1.000000     0.104045    0.145999
# CreditScore                 0.323243      0.104045     1.000000    0.327664
# Experience                  0.982980      0.145999     0.327664    1.000000
# LoanAmount                 -0.007492     -0.004116    -0.010834   -0.007921
# LoanDuration               -0.006992      0.002972    -0.000762   -0.007924
# NumberOfDependents         -0.000287     -0.001244    -0.014453    0.000136
# MonthlyDebtPayments         0.015685     -0.001082     0.011153    0.018629
# CreditCardUtilizationRate  -0.001394     -0.007935    -0.009650   -0.001751
# NumberOfOpenCreditLines    -0.001069     -0.008175    -0.008780   -0.002143
# NumberOfCreditInquiries    -0.002165     -0.005016    -0.001928   -0.002905
# DebtToIncomeRatio           0.004438      0.001507     0.001913    0.003139
# BankruptcyHistory           0.010817      0.003816     0.008638    0.009600
# PreviousLoanDefaults       -0.003684      0.004302    -0.007690   -0.002459
# PaymentHistory             -0.002487      0.003715     0.004295   -0.003346
# LengthOfCreditHistory      -0.000139     -0.005365     0.005217   -0.001132
# SavingsAccountBalance       0.004236     -0.001397    -0.006316    0.005876
# CheckingAccountBalance      0.010145      0.008613     0.005515    0.009292
# TotalAssets                 0.012210     -0.005158     0.001342    0.013074
# TotalLiabilities           -0.001197     -0.002353    -0.006722   -0.000449
# MonthlyIncome               0.144634      0.989911     0.104796    0.145950
# UtilityBillsPaymentHistory -0.005601     -0.012351    -0.006838   -0.006603
# JobTenure                  -0.000773     -0.000610     0.008069   -0.000762
# NetWorth                    0.014061     -0.004358     0.001951    0.015049
# BaseInterestRate           -0.238995     -0.074549    -0.722619   -0.242871
# InterestRate               -0.202702     -0.063832    -0.598844   -0.206252
# MonthlyLoanPayment         -0.021380     -0.004304    -0.063932   -0.021691
# TotalDebtToIncomeRatio     -0.111800     -0.532033    -0.115363   -0.112825
# RiskScore                  -0.164304     -0.483289    -0.240198   -0.166496
#
#                             LoanAmount  LoanDuration  NumberOfDependents  \
# Age                          -0.007492     -0.006992           -0.000287
# AnnualIncome                 -0.004116      0.002972           -0.001244
# CreditScore                  -0.010834     -0.000762           -0.014453
# Experience                   -0.007921     -0.007924            0.000136
# LoanAmount                    1.000000     -0.000436           -0.007005
# LoanDuration                 -0.000436      1.000000           -0.001301
# NumberOfDependents           -0.007005     -0.001301            1.000000
# MonthlyDebtPayments           0.021103      0.000068           -0.002396
# CreditCardUtilizationRate     0.000806     -0.006160            0.011544
# NumberOfOpenCreditLines       0.000769      0.001489            0.006033
# NumberOfCreditInquiries      -0.006239      0.000978           -0.003749
# DebtToIncomeRatio            -0.009577      0.001913           -0.007981
# BankruptcyHistory             0.004844     -0.000434           -0.001154
# PreviousLoanDefaults         -0.002352      0.015646            0.006116
# PaymentHistory               -0.002811      0.001983            0.001281
# LengthOfCreditHistory         0.000580      0.013693            0.002705
# SavingsAccountBalance         0.001489      0.001579           -0.002080
# CheckingAccountBalance        0.005408     -0.002832            0.002485
# TotalAssets                  -0.004238     -0.008297           -0.006284
# TotalLiabilities              0.000502      0.003668            0.009942
# MonthlyIncome                -0.005407      0.003067           -0.000414
# UtilityBillsPaymentHistory   -0.012107     -0.010105            0.008735
# JobTenure                     0.005364      0.003635            0.010910
# NetWorth                     -0.003679     -0.008779           -0.008423
# BaseInterestRate              0.385663      0.579215            0.006977
# InterestRate                  0.322824      0.487994            0.006749
# MonthlyLoanPayment            0.780828     -0.385495           -0.001390
# TotalDebtToIncomeRatio        0.457175     -0.213984           -0.000358
# RiskScore                     0.137981      0.054550            0.001686
#
#                             MonthlyDebtPayments  CreditCardUtilizationRate  \
# Age                                    0.015685                  -0.001394
# AnnualIncome                          -0.001082                  -0.007935
# CreditScore                            0.011153                  -0.009650
# Experience                             0.018629                  -0.001751
# LoanAmount                             0.021103                   0.000806
# LoanDuration                           0.000068                  -0.006160
# NumberOfDependents                    -0.002396                   0.011544
# MonthlyDebtPayments                    1.000000                   0.005420
# CreditCardUtilizationRate              0.005420                   1.000000
# NumberOfOpenCreditLines                0.006280                   0.001491
# NumberOfCreditInquiries                0.009889                   0.001708
# DebtToIncomeRatio                      0.001205                   0.002231
# BankruptcyHistory                     -0.007493                   0.010892
# PreviousLoanDefaults                   0.002713                  -0.004450
# PaymentHistory                        -0.003347                   0.004517
# LengthOfCreditHistory                 -0.004115                   0.007446
# SavingsAccountBalance                 -0.004223                   0.004026
# CheckingAccountBalance                 0.001909                  -0.002115
# TotalAssets                            0.003070                  -0.005047
# TotalLiabilities                      -0.004211                  -0.007778
# MonthlyIncome                         -0.000356                  -0.009381
# UtilityBillsPaymentHistory             0.001638                   0.013040
# JobTenure                              0.005863                  -0.006979
# NetWorth                               0.004430                  -0.003506
# BaseInterestRate                       0.000010                   0.003668
# InterestRate                           0.003895                   0.001030
# MonthlyLoanPayment                     0.018021                   0.004366
# TotalDebtToIncomeRatio                 0.219453                   0.010490
# RiskScore                              0.036938                   0.108758
#
#                             NumberOfOpenCreditLines  ...  TotalLiabilities  \
# Age                                       -0.001069  ...         -0.001197
# AnnualIncome                              -0.008175  ...         -0.002353
# CreditScore                               -0.008780  ...         -0.006722
# Experience                                -0.002143  ...         -0.000449
# LoanAmount                                 0.000769  ...          0.000502
# LoanDuration                               0.001489  ...          0.003668
# NumberOfDependents                         0.006033  ...          0.009942
# MonthlyDebtPayments                        0.006280  ...         -0.004211
# CreditCardUtilizationRate                  0.001491  ...         -0.007778
# NumberOfOpenCreditLines                    1.000000  ...         -0.008406
# NumberOfCreditInquiries                    0.000446  ...          0.000141
# DebtToIncomeRatio                          0.004363  ...         -0.002644
# BankruptcyHistory                         -0.001612  ...         -0.001229
# PreviousLoanDefaults                       0.012600  ...         -0.003732
# PaymentHistory                             0.002388  ...         -0.011324
# LengthOfCreditHistory                      0.003653  ...          0.000318
# SavingsAccountBalance                      0.009167  ...         -0.002128
# CheckingAccountBalance                    -0.005282  ...          0.001473
# TotalAssets                               -0.003896  ...         -0.000276
# TotalLiabilities                          -0.008406  ...          1.000000
# MonthlyIncome                             -0.008050  ...         -0.001761
# UtilityBillsPaymentHistory                -0.010497  ...         -0.006187
# JobTenure                                  0.007298  ...         -0.003399
# NetWorth                                  -0.002013  ...         -0.129962
# BaseInterestRate                           0.007457  ...          0.007140
# InterestRate                               0.008090  ...          0.010176
# MonthlyLoanPayment                        -0.005058  ...         -0.001668
# TotalDebtToIncomeRatio                     0.003471  ...         -0.002427
# RiskScore                                  0.007762  ...          0.055617
#
#                             MonthlyIncome  UtilityBillsPaymentHistory  \
# Age                              0.144634                   -0.005601
# AnnualIncome                     0.989911                   -0.012351
# CreditScore                      0.104796                   -0.006838
# Experience                       0.145950                   -0.006603
# LoanAmount                      -0.005407                   -0.012107
# LoanDuration                     0.003067                   -0.010105
# NumberOfDependents              -0.000414                    0.008735
# MonthlyDebtPayments             -0.000356                    0.001638
# CreditCardUtilizationRate       -0.009381                    0.013040
# NumberOfOpenCreditLines         -0.008050                   -0.010497
# NumberOfCreditInquiries         -0.005155                    0.005488
# DebtToIncomeRatio                0.001677                   -0.014412
# BankruptcyHistory                0.003855                   -0.002335
# PreviousLoanDefaults             0.004639                   -0.011716
# PaymentHistory                   0.003335                    0.010530
# LengthOfCreditHistory           -0.005526                    0.006534
# SavingsAccountBalance           -0.001572                   -0.008145
# CheckingAccountBalance           0.009233                   -0.005696
# TotalAssets                     -0.004128                   -0.000479
# TotalLiabilities                -0.001761                   -0.006187
# MonthlyIncome                    1.000000                   -0.010641
# UtilityBillsPaymentHistory      -0.010641                    1.000000
# JobTenure                       -0.001422                   -0.007986
# NetWorth                        -0.003284                   -0.000968
# BaseInterestRate                -0.075522                   -0.005517
# InterestRate                    -0.064565                   -0.004051
# MonthlyLoanPayment              -0.005905                   -0.007481
# TotalDebtToIncomeRatio          -0.538314                    0.006942
# RiskScore                       -0.487039                   -0.005196
#
#                             JobTenure  NetWorth  BaseInterestRate  \
# Age                         -0.000773  0.014061         -0.238995
# AnnualIncome                -0.000610 -0.004358         -0.074549
# CreditScore                  0.008069  0.001951         -0.722619
# Experience                  -0.000762  0.015049         -0.242871
# LoanAmount                   0.005364 -0.003679          0.385663
# LoanDuration                 0.003635 -0.008779          0.579215
# NumberOfDependents           0.010910 -0.008423          0.006977
# MonthlyDebtPayments          0.005863  0.004430          0.000010
# CreditCardUtilizationRate   -0.006979 -0.003506          0.003668
# NumberOfOpenCreditLines      0.007298 -0.002013          0.007457
# NumberOfCreditInquiries      0.002794  0.004829         -0.000409
# DebtToIncomeRatio            0.009165 -0.008803         -0.003888
# BankruptcyHistory            0.004436 -0.000833         -0.004623
# PreviousLoanDefaults         0.003628  0.008605          0.013689
# PaymentHistory              -0.007882 -0.002853         -0.002999
# LengthOfCreditHistory        0.015104  0.004313          0.004399
# SavingsAccountBalance       -0.004250  0.003458          0.006012
# CheckingAccountBalance      -0.002440  0.001596         -0.003554
# TotalAssets                  0.007057  0.978997         -0.007368
# TotalLiabilities            -0.003399 -0.129962          0.007140
# MonthlyIncome               -0.001422 -0.003284         -0.075522
# UtilityBillsPaymentHistory  -0.007986 -0.000968         -0.005517
# JobTenure                    1.000000  0.005832         -0.001661
# NetWorth                     0.005832  1.000000         -0.007874
# BaseInterestRate            -0.001661 -0.007874          1.000000
# InterestRate                -0.004422 -0.006422          0.834557
# MonthlyLoanPayment           0.004067  0.000168          0.118030
# TotalDebtToIncomeRatio       0.005206 -0.005966          0.131853
# RiskScore                   -0.004393 -0.304333          0.256233
#
#                             InterestRate  MonthlyLoanPayment  \
# Age                            -0.202702           -0.021380
# AnnualIncome                   -0.063832           -0.004304
# CreditScore                    -0.598844           -0.063932
# Experience                     -0.206252           -0.021691
# LoanAmount                      0.322824            0.780828
# LoanDuration                    0.487994           -0.385495
# NumberOfDependents              0.006749           -0.001390
# MonthlyDebtPayments             0.003895            0.018021
# CreditCardUtilizationRate       0.001030            0.004366
# NumberOfOpenCreditLines         0.008090           -0.005058
# NumberOfCreditInquiries        -0.005468           -0.003395
# DebtToIncomeRatio              -0.006106           -0.007974
# BankruptcyHistory               0.002591            0.006279
# PreviousLoanDefaults            0.008299           -0.011763
# PaymentHistory                  0.002030           -0.000883
# LengthOfCreditHistory           0.004991           -0.010042
# SavingsAccountBalance           0.002731            0.000212
# CheckingAccountBalance         -0.001943            0.002281
# TotalAssets                    -0.005807           -0.000875
# TotalLiabilities                0.010176           -0.001668
# MonthlyIncome                  -0.064565           -0.005905
# UtilityBillsPaymentHistory     -0.004051           -0.007481
# JobTenure                      -0.004422            0.004067
# NetWorth                       -0.006422            0.000168
# BaseInterestRate                0.834557            0.118030
# InterestRate                    1.000000            0.127497
# MonthlyLoanPayment              0.127497            1.000000
# TotalDebtToIncomeRatio          0.131765            0.567842
# RiskScore                       0.268203            0.115501
#
#                             TotalDebtToIncomeRatio  RiskScore
# Age                                      -0.111800  -0.164304
# AnnualIncome                             -0.532033  -0.483289
# CreditScore                              -0.115363  -0.240198
# Experience                               -0.112825  -0.166496
# LoanAmount                                0.457175   0.137981
# LoanDuration                             -0.213984   0.054550
# NumberOfDependents                       -0.000358   0.001686
# MonthlyDebtPayments                       0.219453   0.036938
# CreditCardUtilizationRate                 0.010490   0.108758
# NumberOfOpenCreditLines                   0.003471   0.007762
# NumberOfCreditInquiries                  -0.002913   0.003103
# DebtToIncomeRatio                        -0.013076   0.326500
# BankruptcyHistory                        -0.000702   0.377578
# PreviousLoanDefaults                     -0.000458   0.258659
# PaymentHistory                            0.003420  -0.016992
# LengthOfCreditHistory                    -0.009381  -0.177796
# SavingsAccountBalance                    -0.003484   0.002190
# CheckingAccountBalance                   -0.006630  -0.004044
# TotalAssets                              -0.007333  -0.297117
# TotalLiabilities                         -0.002427   0.055617
# MonthlyIncome                            -0.538314  -0.487039
# UtilityBillsPaymentHistory                0.006942  -0.005196
# JobTenure                                 0.005206  -0.004393
# NetWorth                                 -0.005966  -0.304333
# BaseInterestRate                          0.131853   0.256233
# InterestRate                              0.131765   0.268203
# MonthlyLoanPayment                        0.567842   0.115501
# TotalDebtToIncomeRatio                    1.000000   0.342643
# RiskScore                                 0.342643   1.000000
#
# [29 rows x 29 columns]

# %%
# Матрица корреляции в виде карты тепла
sns.heatmap(corr_data)
# Out:
# <Axes: >

# %% [markdown]
# **Основные наблюдения:**
#
#     1) Средний возраст - ~40 лет. Максимальный - 80, минимальный - 18.
#     2) Средняя сумма кредита - ~25000. Максимальная - 184732, минимальная - 3674.
#     3) Некоторые переменные имеют высокую корреляцию. Для некоторых это оправдывается логической связью (опыт в кредитах и возраст), для некоторых - тем, что они связаны напрямую (фактический доход и зарплата).

# %%
# Гистограммы численных столбцов
raw_data.hist(grid=False, layout=(5, 6), figsize=(15, 10))
plt.tight_layout()
plt.show()

# %%
# Boxplot'ы некоторых исходных численных данных и их "обработанное представление" (Отбрасываем только там, где есть отклонения)
for_use_data = raw_data

f, axes = plt.subplots(28, 2)
f.set_figheight(150)
f.set_figwidth(10)

k = 0
for feat in numeric_feat:
    sns.boxplot(raw_data[feat], ax=axes[k, 0])
    k += 1

q = raw_data['Age'].quantile(0.95)
for_use_data = for_use_data[for_use_data['Age'] < q]
q = raw_data['AnnualIncome'].quantile(0.925)
for_use_data = for_use_data[for_use_data['AnnualIncome'] < q]
q = raw_data['CreditScore'].quantile(0.05)
for_use_data = for_use_data[for_use_data['CreditScore'] > q]
q = raw_data['Experience'].quantile(0.95)
for_use_data = for_use_data[for_use_data['Experience'] < q]
q = raw_data['LoanAmount'].quantile(0.925)
for_use_data = for_use_data[for_use_data['LoanAmount'] < q]
q = raw_data['MonthlyDebtPayments'].quantile(0.94)
for_use_data = for_use_data[for_use_data['MonthlyDebtPayments'] < q]
q = raw_data['CreditCardUtilizationRate'].quantile(0.95)
for_use_data = for_use_data[for_use_data['CreditCardUtilizationRate'] < q]
q = raw_data['NumberOfOpenCreditLines'].quantile(0.95)
for_use_data = for_use_data[for_use_data['NumberOfOpenCreditLines'] < q]
q = raw_data['NumberOfCreditInquiries'].quantile(0.95)
for_use_data = for_use_data[for_use_data['NumberOfCreditInquiries'] < q]
q = raw_data['DebtToIncomeRatio'].quantile(0.95)
for_use_data = for_use_data[for_use_data['DebtToIncomeRatio'] < q]
q = raw_data['BankruptcyHistory'].quantile(0.95)
for_use_data = for_use_data[for_use_data['BankruptcyHistory'] < q]
q = raw_data['PreviousLoanDefaults'].quantile(0.95)
for_use_data = for_use_data[for_use_data['PreviousLoanDefaults'] < q]
q1 = raw_data['PaymentHistory'].quantile(0.95)
q2 = raw_data['PaymentHistory'].quantile(0.05)
for_use_data = for_use_data[(for_use_data['PaymentHistory'] < q1) & (for_use_data['PaymentHistory'] > q2)]
q = raw_data['SavingsAccountBalance'].quantile(0.875)
for_use_data = for_use_data[for_use_data['SavingsAccountBalance'] < q]
q = raw_data['CheckingAccountBalance'].quantile(0.865)
for_use_data = for_use_data[for_use_data['CheckingAccountBalance'] < q]
q = raw_data['TotalAssets'].quantile(0.865)
for_use_data = for_use_data[for_use_data['TotalAssets'] < q]
q = raw_data['TotalLiabilities'].quantile(0.875)
for_use_data = for_use_data[for_use_data['TotalLiabilities'] < q]
q = raw_data['UtilityBillsPaymentHistory'].quantile(0.05)
for_use_data = for_use_data[for_use_data['UtilityBillsPaymentHistory'] > q]
q = raw_data['JobTenure'].quantile(0.95)
for_use_data = for_use_data[for_use_data['JobTenure'] < q]
q = raw_data['NetWorth'].quantile(0.85)
for_use_data = for_use_data[for_use_data['NetWorth'] < q]
q1 = raw_data['BaseInterestRate'].quantile(0.95)
q2 = raw_data['BaseInterestRate'].quantile(0.05)
for_use_data = for_use_data[(for_use_data['BaseInterestRate'] < q1) & (for_use_data['BaseInterestRate'] > q2)]
q = raw_data['InterestRate'].quantile(0.95)
for_use_data = for_use_data[for_use_data['InterestRate'] < q]
q = raw_data['MonthlyLoanPayment'].quantile(0.875)
for_use_data = for_use_data[for_use_data['MonthlyLoanPayment'] < q]
q = raw_data['TotalDebtToIncomeRatio'].quantile(0.875)
for_use_data = for_use_data[for_use_data['TotalDebtToIncomeRatio'] < q]

k = 0
for feat in numeric_feat:
    sns.boxplot(for_use_data[feat], ax=axes[k, 1])
    k += 1

plt.show()

# %%
plt.pie(for_use_data['EmploymentStatus'].value_counts().values,labels = list(for_use_data['EmploymentStatus'].unique()))
# Out:
# ([<matplotlib.patches.Wedge at 0x27cf6f6c430>,
#   <matplotlib.patches.Wedge at 0x27cf6f6c4f0>,
#   <matplotlib.patches.Wedge at 0x27cfdd31cd0>],
#  [Text(-0.9819503485146669, 0.49575549724831525, 'Employed'),
#   Text(0.8554840669579199, -0.691481750432459, 'Unemployed'),
#   Text(1.075317067836573, -0.2317179397874816, 'Self-Employed')])

# %%
plt.pie(for_use_data['EducationLevel'].value_counts().values,labels = list(for_use_data['EducationLevel'].unique()))
# Out:
# ([<matplotlib.patches.Wedge at 0x27c826ed2b0>,
#   <matplotlib.patches.Wedge at 0x27c826ed1f0>,
#   <matplotlib.patches.Wedge at 0x27c826eda60>,
#   <matplotlib.patches.Wedge at 0x27c826edee0>,
#   <matplotlib.patches.Wedge at 0x27c826fa3a0>],
#  [Text(0.6370835862154978, 0.8967298947703264, 'High School'),
#   Text(-1.0376205075631983, 0.3651625422798606, 'Associate'),
#   Text(-0.36100441512846304, -1.039074497934463, 'Bachelor'),
#   Text(0.8094533194419817, -0.7448391260160527, 'Doctorate'),
#   Text(1.0906968508946566, -0.14275986637875226, 'Master')])

# %%
plt.pie(for_use_data['MaritalStatus'].value_counts().values,labels = list(for_use_data['MaritalStatus'].unique()))
# Out:
# ([<matplotlib.patches.Wedge at 0x27c8273a7c0>,
#   <matplotlib.patches.Wedge at 0x27c82727910>,
#   <matplotlib.patches.Wedge at 0x27c827490d0>,
#   <matplotlib.patches.Wedge at 0x27c82749550>],
#  [Text(-0.007708695945594425, 1.0999729887623688, 'Single'),
#   Text(-0.6208215582911896, -0.9080642007924877, 'Married'),
#   Text(0.8087070779110086, -0.7456492889667622, 'Divorced'),
#   Text(1.0895184659810433, -0.15149096437185428, 'Widowed')])

# %%
plt.pie(for_use_data['HomeOwnershipStatus'].value_counts().values,labels = list(for_use_data['HomeOwnershipStatus'].unique()))
# Out:
# ([<matplotlib.patches.Wedge at 0x27c82787d30>,
#   <matplotlib.patches.Wedge at 0x27c82787c70>,
#   <matplotlib.patches.Wedge at 0x27c827964c0>,
#   <matplotlib.patches.Wedge at 0x27c82796940>],
#  [Text(0.3390807115043986, 1.0464340739318798, 'Mortgage'),
#   Text(-1.0460941104476082, -0.3401280818850853, 'Rent'),
#   Text(0.36100426920069534, -1.039074548633962, 'Own'),
#   Text(1.0530131958330817, -0.31806164402738035, 'Other')])

# %%
plt.pie(for_use_data['LoanPurpose'].value_counts().values,labels = list(for_use_data['LoanPurpose'].unique()))
# Out:
# ([<matplotlib.patches.Wedge at 0x27c827dd490>,
#   <matplotlib.patches.Wedge at 0x27c827dd3d0>,
#   <matplotlib.patches.Wedge at 0x27c827ddc70>,
#   <matplotlib.patches.Wedge at 0x27c827ee130>,
#   <matplotlib.patches.Wedge at 0x27c827ee5b0>],
#  [Text(0.6513653474335169, 0.8864102798156246, 'Home'),
#   Text(-0.9723431251454484, 0.5143431218383143, 'Auto'),
#   Text(-0.6828826746381453, -0.8623637589086482, 'Debt Consolidation'),
#   Text(0.4520334473752264, -1.0028288799461595, 'Education'),
#   Text(1.0405118502926434, -0.3568404256815365, 'Other')])

# %% [markdown]
# ## **3. Обработать пропущенные значения (или убедиться, что их нет)**

# %% [markdown]
# В данном датасете нет пропущенных значений в исходном представлении (как пустые поля). Вместо этого во многих строковыых признаках присутствуют значения "Other", заполняющие их места.

# %% [markdown]
# ## **4. Обработать категориальные признаки**

# %%
for_use_data = pd.get_dummies(for_use_data, columns=['EmploymentStatus', 'EducationLevel', 'MaritalStatus', 'HomeOwnershipStatus', 'LoanPurpose'], drop_first=True)

# %% [markdown]
# ## **5. Провести нормализацию (или объяснить, почему в вашем случае она не нужна)**

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

for_use_data[numeric_feat] = scaler.fit_transform(for_use_data[numeric_feat])

# %%
for_use_data = for_use_data.astype(float) # Для того, чтобы изавиться от boolean переменных

for_use_data
# Out:
#             Age  AnnualIncome  CreditScore  Experience  LoanAmount  \
# 3      1.979662      0.635843    -0.789746    1.867153    2.042305
# 23    -1.662539      0.402801    -1.847138   -1.687761   -0.533598
# 29    -0.246128      0.278988    -0.009291   -0.223973    0.523121
# 32     0.057389      0.314122    -0.437282    0.298808   -1.301006
# 40     0.967939     -0.598302     0.469053    1.030703    1.154772
# ...         ...           ...          ...         ...         ...
# 19981  0.765595      1.225981    -2.199602    0.717034   -0.480930
# 19984  0.259733     -1.052539    -0.512810    0.403365    0.316299
# 19992  1.170284     -0.766354     0.041061    1.135259    0.910913
# 19996  1.777317     -0.163444    -0.235875    1.762597    0.589737
# 19997  0.563250     -0.175048     1.727853    0.403365    1.938293
#
#        LoanDuration  NumberOfDependents  MonthlyDebtPayments  \
# 3          1.799215           -0.377676             2.057281
# 23        -1.492876            0.351645            -0.179274
# 29         1.250533            1.080967             0.304625
# 32         1.250533           -1.106997            -0.155669
# 40        -0.395513           -1.106997             0.906547
# ...             ...                 ...                  ...
# 19981     -0.944194           -0.377676            -0.521544
# 19984      0.153169            1.080967             1.000966
# 19992     -0.395513            1.080967             0.168897
# 19996     -0.944194            2.539609             0.044972
# 19997      0.701851            1.080967             0.623289
#
#        CreditCardUtilizationRate  NumberOfOpenCreditLines  ...  \
# 3                      -0.001102                -0.491813  ...
# 23                      0.886384                 0.238229  ...
# 29                      0.076609                 0.238229  ...
# 32                     -1.013453                -1.221856  ...
# 40                      0.833950                -1.951899  ...
# ...                          ...                      ...  ...
# 19981                  -0.177586                 0.238229  ...
# 19984                   0.471924                -0.491813  ...
# 19992                   1.001669                -0.491813  ...
# 19996                   1.483810                -0.491813  ...
# 19997                  -0.371845                 0.238229  ...
#
#        MaritalStatus_Married  MaritalStatus_Single  MaritalStatus_Widowed  \
# 3                        0.0                   1.0                    0.0
# 23                       1.0                   0.0                    0.0
# 29                       0.0                   0.0                    0.0
# 32                       1.0                   0.0                    0.0
# 40                       0.0                   0.0                    0.0
# ...                      ...                   ...                    ...
# 19981                    0.0                   1.0                    0.0
# 19984                    1.0                   0.0                    0.0
# 19992                    0.0                   1.0                    0.0
# 19996                    1.0                   0.0                    0.0
# 19997                    1.0                   0.0                    0.0
#
#        HomeOwnershipStatus_Other  HomeOwnershipStatus_Own  \
# 3                            0.0                      0.0
# 23                           0.0                      0.0
# 29                           0.0                      1.0
# 32                           0.0                      0.0
# 40                           0.0                      1.0
# ...                          ...                      ...
# 19981                        0.0                      1.0
# 19984                        0.0                      0.0
# 19992                        0.0                      0.0
# 19996                        0.0                      0.0
# 19997                        0.0                      0.0
#
#        HomeOwnershipStatus_Rent  LoanPurpose_Debt Consolidation  \
# 3                           0.0                             0.0
# 23                          1.0                             0.0
# 29                          0.0                             0.0
# 32                          0.0                             0.0
# 40                          0.0                             0.0
# ...                         ...                             ...
# 19981                       0.0                             1.0
# 19984                       1.0                             0.0
# 19992                       0.0                             1.0
# 19996                       1.0                             1.0
# 19997                       0.0                             0.0
#
#        LoanPurpose_Education  LoanPurpose_Home  LoanPurpose_Other
# 3                        0.0               1.0                0.0
# 23                       0.0               1.0                0.0
# 29                       0.0               1.0                0.0
# 32                       0.0               0.0                0.0
# 40                       0.0               1.0                0.0
# ...                      ...               ...                ...
# 19981                    0.0               0.0                0.0
# 19984                    0.0               0.0                1.0
# 19992                    0.0               0.0                0.0
# 19996                    0.0               0.0                0.0
# 19997                    0.0               1.0                0.0
#
# [3138 rows x 45 columns]

# %% [markdown]
# ## **6. Разбить данные на обучающую и тестовую выборки**

# %%
from sklearn.model_selection import train_test_split
from numpy import log

X = for_use_data.drop(['RiskScore'], axis=1)
y = [log(item) for item in for_use_data['RiskScore']] # Уменьшение разброса

X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state=42, test_size=0.25
)

# %% [markdown]
# ## **7. Запустить классификатор (ререссию) ближайших соседей или другой метод (аргументируйте выбор!)**

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor

model_linreg = LinearRegression().fit(X_train, y_train)

y_pred_train_linreg = model_linreg.predict(X_train)
y_pred_test_linreg = model_linreg.predict(X_test)

# %% [markdown]
# ## **8. Вычислить ошибки на обучающей и тестовой выборках. Выбрать оптимальное значение гиперпараметра (к-ва ближайших соседей) Сделать выводы**

# %%
from sklearn.metrics import mean_squared_error

# %%
print("Среднеквадратичная ошибка для предсказания оценки риска при выдаче кредита (линейная регрессия, обучающая выборка):")
print(mean_squared_error(y_train, y_pred_train_linreg))
# Out:
# Среднеквадратичная ошибка для предсказания оценки риска при выдаче кредита (линейная регрессия, обучающая выборка):
# 0.0045824403463293395

# %%
print("Среднеквадратичная ошибка для предсказания оценки риска при выдаче кредита (линейная регрессия, тестовая выборка):")
print(mean_squared_error(y_test, y_pred_test_linreg))
# Out:
# Среднеквадратичная ошибка для предсказания оценки риска при выдаче кредита (линейная регрессия, тестовая выборка):
# 0.0049335026153203496

# %%
train_err = []
test_err = []
neigh_range = range(1, 21)

for k in neigh_range:
    model_kneigh = KNeighborsRegressor(n_neighbors=k).fit(X_train, y_train)

    train_err.append(mean_squared_error(y_train, model_kneigh.predict(X_train)))
    test_err.append(mean_squared_error(y_test, model_kneigh.predict(X_test)))

plt.figure(figsize=(10, 10))
plt.plot(neigh_range, train_err, label="Среднеквадратичная ошибка на обучающей выборке")
plt.plot(neigh_range, test_err, label="Среднеквадратичная ошибка на тестовой выборке")
plt.xlabel("Количество соседей (k)")
plt.ylabel("Среднеквадратичная ошибка")
plt.legend()
plt.title("Ошибка регрессии на основе k ближайших соседей в зависимости от числа соседей")
plt.show()

optimal_k = neigh_range[test_err.index(min(test_err))]
print("Оптимальное количество соседей:", optimal_k)
print("Среднеквадратичная ошибка при оптимальном количестве соседей:", min(test_err))
# Out:
# Оптимальное количество соседей: 11
# Среднеквадратичная ошибка при оптимальном количестве соседей: 0.007127244904620224

# %% [markdown]
# ## **12. Сделать общие выводы**

# %% [markdown]
#     1) Исходные данные имели большой разброс в столбце оценки риска при выдаче кредита. Используя логарифмирование, удалось достичь меньшего разброса, что положительно сказывается на результате обучения модели.
#     2) Категориальные признаки были сведены к столбцам с бинарнми значениями, таким образом было удалено использоание строчнх значений.
